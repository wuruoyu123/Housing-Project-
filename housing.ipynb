# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plot
# %matplotlib inline
import seaborn as sns

# To read xlsx:
#!pip install openpyxl

# %% [markdown]
# # 1. Exploratory analysis:

# %%
#import training dataset

# To read the date column correctly, we can use the argument parse_dates to specify a list of date columns.
train_data = pd.read_csv('train_2016.csv', parse_dates=["transactiondate"]) 
properties_data = pd.read_csv('properties_2016.csv',low_memory=False)

# %%
train_data.head()
# Out:
#    parcelid  logerror transactiondate
# 0  11016594     0.028      2016-01-01
# 1  14366692    -0.168      2016-01-01
# 2  12098116    -0.004      2016-01-01
# 3  12643413     0.022      2016-01-02
# 4  14432541    -0.005      2016-01-02

# %%
properties_data.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  bathroomcnt  \
# 0  10754147                    NaN                       NaN           NaN          0.0
# 1  10759547                    NaN                       NaN           NaN          0.0
# 2  10843547                    NaN                       NaN           NaN          0.0
# 3  10859147                    NaN                       NaN           NaN          0.0
# 4  10879947                    NaN                       NaN           NaN          0.0
#
#    bedroomcnt  buildingclasstypeid  buildingqualitytypeid  calculatedbathnbr  decktypeid  ...  \
# 0         0.0                  NaN                    NaN                NaN         NaN  ...
# 1         0.0                  NaN                    NaN                NaN         NaN  ...
# 2         0.0                  NaN                    NaN                NaN         NaN  ...
# 3         0.0                  3.0                    7.0                NaN         NaN  ...
# 4         0.0                  4.0                    NaN                NaN         NaN  ...
#
#    numberofstories  fireplaceflag  structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0              NaN            NaN                         NaN          9.000e+00          2015.0
# 1              NaN            NaN                         NaN          2.752e+04          2015.0
# 2              NaN            NaN                    650756.0          1.413e+06          2015.0
# 3              1.0            NaN                    571346.0          1.157e+06          2015.0
# 4              NaN            NaN                    193796.0          4.335e+05          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  censustractandblock
# 0                    9.0        NaN                 NaN                 NaN                  NaN
# 1                27516.0        NaN                 NaN                 NaN                  NaN
# 2               762631.0   20800.37                 NaN                 NaN                  NaN
# 3               585488.0   14557.57                 NaN                 NaN                  NaN
# 4               239695.0    5725.17                 NaN                 NaN                  NaN
#
# [5 rows x 58 columns]

# %%
dict_data = pd.read_excel('zillow_data_dictionary.xlsx')
dict_data
# Out:
#                            Feature                                        Description
# 0          'airconditioningtypeid'   Type of cooling system present in the home (i...
# 1       'architecturalstyletypeid'   Architectural style of the home (i.e. ranch, ...
# 2                   'basementsqft'   Finished living area below or partially below...
# 3                    'bathroomcnt'   Number of bathrooms in home including fractio...
# 4                     'bedroomcnt'                        Number of bedrooms in home
# 5          'buildingqualitytypeid'   Overall assessment of condition of the buildi...
# 6            'buildingclasstypeid'  The building framing type (steel frame, wood f...
# 7              'calculatedbathnbr'   Number of bathrooms in home including fractio...
# 8                     'decktypeid'            Type of deck (if any) present on parcel
# 9            'threequarterbathnbr'   Number of 3/4 bathrooms in house (shower + si...
# 10      'finishedfloor1squarefeet'   Size of the finished living area on the first...
# 11  'calculatedfinishedsquarefeet'   Calculated total finished living area of the ...
# 12           'finishedsquarefeet6'                  Base unfinished and finished area
# 13          'finishedsquarefeet12'                               Finished living area
# 14          'finishedsquarefeet13'                             Perimeter  living area
# 15          'finishedsquarefeet15'                                         Total area
# 16          'finishedsquarefeet50'   Size of the finished living area on the first...
# 17                          'fips'   Federal Information Processing Standard code ...
# 18                  'fireplacecnt'            Number of fireplaces in a home (if any)
# 19                 'fireplaceflag'               Is a fireplace present in this home
# 20                   'fullbathcnt'   Number of full bathrooms (sink, shower + bath...
# 21                  'garagecarcnt'   Total number of garages on the lot including ...
# 22               'garagetotalsqft'   Total number of square feet of all garages on...
# 23                'hashottuborspa'                Does the home have a hot tub or spa
# 24         'heatingorsystemtypeid'                        Type of home heating system
# 25                      'latitude'   Latitude of the middle of the parcel multipli...
# 26                     'longitude'   Longitude of the middle of the parcel multipl...
# 27             'lotsizesquarefeet'                     Area of the lot in square feet
# 28               'numberofstories'           Number of stories or levels the home has
# 29                      'parcelid'              Unique identifier for parcels (lots)
# 30                       'poolcnt'                Number of pools on the lot (if any)
# 31                   'poolsizesum'      Total square footage of all pools on property
# 32                  'pooltypeid10'                                     Spa or Hot Tub
# 33                   'pooltypeid2'                              Pool with Spa/Hot Tub
# 34                   'pooltypeid7'                               Pool without hot tub
# 35     'propertycountylandusecode'   County land use code i.e. it's zoning at the ...
# 36         'propertylandusetypeid'         Type of land use the property is zoned for
# 37            'propertyzoningdesc'   Description of the allowed land uses (zoning)...
# 38        'rawcensustractandblock'   Census tract and block ID combined - also con...
# 39           'censustractandblock'   Census tract and block ID combined - also con...
# 40                'regionidcounty'            County in which the property is located
# 41                  'regionidcity'     City in which the property is located (if any)
# 42                   'regionidzip'          Zip code in which the property is located
# 43          'regionidneighborhood'      Neighborhood in which the property is located
# 44                       'roomcnt'   Total number of rooms in the principal residence
# 45                   'storytypeid'   Type of floors in a multi-story house (i.e. b...
# 46        'typeconstructiontypeid'   What type of construction material was used t...
# 47                       'unitcnt'   Number of units the structure is built into (...
# 48            'yardbuildingsqft17'                                     Patio in  yard
# 49            'yardbuildingsqft26'                      Storage shed/building in yard
# 50                     'yearbuilt'        The Year the principal residence was built
# 51             'taxvaluedollarcnt'         The total tax assessed value of the parcel
# 52    'structuretaxvaluedollarcnt'  The assessed value of the built structure on t...
# 53         'landtaxvaluedollarcnt'  The assessed value of the land area of the parcel
# 54                     'taxamount'  The total property tax assessed for that asses...
# 55                'assessmentyear'           The year of the property tax assessment
# 56            'taxdelinquencyflag'  Property taxes for this parcel are past due as...
# 57            'taxdelinquencyyear'  Year for which the unpaid propert taxes were due

# %%
#shape of the data
print ("Shape of the train_2016 dataset:",train_data.shape)
print ("Shape of the properties_2016 dataset:",properties_data.shape)
# Out:
# Shape of the train_2016 dataset: (90275, 3)
# Shape of the properties_2016 dataset: (2985217, 58)

# %% [markdown]
# ### -> Since train dataset has 90275 row and properties has 2985217 rows, let's merge the dataset together.

# %%
# left join these 2 tables:
merged_train_data = pd.merge(train_data,properties_data,on="parcelid",how="left")

# %%
merged_train_data.head()
# Out:
#    parcelid  logerror transactiondate  airconditioningtypeid  architecturalstyletypeid  \
# 0  11016594     0.028      2016-01-01                    1.0                       NaN
# 1  14366692    -0.168      2016-01-01                    NaN                       NaN
# 2  12098116    -0.004      2016-01-01                    1.0                       NaN
# 3  12643413     0.022      2016-01-02                    1.0                       NaN
# 4  14432541    -0.005      2016-01-02                    NaN                       NaN
#
#    basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  ...  \
# 0           NaN          2.0         3.0                  NaN                    4.0  ...
# 1           NaN          3.5         4.0                  NaN                    NaN  ...
# 2           NaN          3.0         2.0                  NaN                    4.0  ...
# 3           NaN          2.0         2.0                  NaN                    4.0  ...
# 4           NaN          2.5         4.0                  NaN                    NaN  ...
#
#    numberofstories  fireplaceflag  structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0              NaN            NaN                    122754.0           360170.0          2015.0
# 1              NaN            NaN                    346458.0           585529.0          2015.0
# 2              NaN            NaN                     61994.0           119906.0          2015.0
# 3              NaN            NaN                    171518.0           244880.0          2015.0
# 4              2.0            NaN                    169574.0           434551.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  censustractandblock
# 0               237416.0    6735.88                 NaN                 NaN            6.037e+13
# 1               239071.0   10153.02                 NaN                 NaN                  NaN
# 2                57912.0   11484.48                 NaN                 NaN            6.037e+13
# 3                73362.0    3048.74                 NaN                 NaN            6.037e+13
# 4               264977.0    5488.96                 NaN                 NaN            6.059e+13
#
# [5 rows x 60 columns]

# %%
print ("Shape of the merged_2016 dataset:",merged_train_data.shape)
# Out:
# Shape of the merged_2016 dataset: (90275, 60)

# %% [markdown]
# ## 1.1 Descriptive Statistics

# %%
data = merged_train_data
pd.set_option('display.width', 100)
pd.set_option('precision', 3)
description = data.describe()
print(description)
# Out:
#         parcelid   logerror  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# count  9.028e+04  90275.000              28781.000                   261.000        43.000
# mean   1.298e+07      0.011                  1.816                     7.230       713.581
# std    2.505e+06      0.161                  2.974                     2.716       437.434
# min    1.071e+07     -4.605                  1.000                     2.000       100.000
# 25%    1.156e+07     -0.025                  1.000                     7.000       407.500
# 50%    1.255e+07      0.006                  1.000                     7.000       616.000
# 75%    1.423e+07      0.039                  1.000                     7.000       872.000
# max    1.630e+08      4.737                 13.000                    21.000      1555.000
#
#        bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  calculatedbathnbr  \
# count    90275.000   90275.000                 16.0              57364.000          89093.000
# mean         2.279       3.032                  4.0                  5.565              2.309
# std          1.004       1.156                  0.0                  1.901              0.976
# min          0.000       0.000                  4.0                  1.000              1.000
# 25%          2.000       2.000                  4.0                  4.000              2.000
# 50%          2.000       3.000                  4.0                  7.000              2.000
# 75%          3.000       4.000                  4.0                  7.000              3.000
# max         20.000      16.000                  4.0                 12.000             20.000
#
#        ...  yardbuildingsqft26  yearbuilt  numberofstories  structuretaxvaluedollarcnt  \
# count  ...              95.000  89519.000        20570.000                   8.990e+04
# mean   ...             311.695   1968.533            1.441                   1.801e+05
# std    ...             346.355     23.763            0.544                   2.091e+05
# min    ...              18.000   1885.000            1.000                   1.000e+02
# 25%    ...             100.000   1953.000            1.000                   8.124e+04
# 50%    ...             159.000   1970.000            1.000                   1.320e+05
# 75%    ...             361.000   1987.000            2.000                   2.105e+05
# max    ...            1366.000   2015.000            4.000                   9.948e+06
#
#        taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt   taxamount  taxdelinquencyyear  \
# count          9.027e+04         90275.0              9.027e+04   90269.000            1783.000
# mean           4.577e+05          2015.0              2.783e+05    5983.976              13.403
# std            5.549e+05             0.0              4.005e+05    6838.877               2.716
# min            2.200e+01          2015.0              2.200e+01      49.080               6.000
# 25%            1.990e+05          2015.0              8.223e+04    2872.830              13.000
# 50%            3.429e+05          2015.0              1.930e+05    4542.750              14.000
# 75%            5.406e+05          2015.0              3.454e+05    6901.090              15.000
# max            2.775e+07          2015.0              2.450e+07  321936.090              99.000
#
#        censustractandblock
# count            8.967e+04
# mean             6.049e+13
# std              2.047e+11
# min              6.037e+13
# 25%              6.037e+13
# 50%              6.038e+13
# 75%              6.059e+13
# max              6.111e+13
#
# [8 rows x 54 columns]

# %% [markdown]
# ## 1.2 Non Numerical Data:

# %%
data_type = merged_train_data.dtypes.reset_index()
data_type.columns = ["Count", "Data Type"]
data_type.groupby("Data Type").aggregate('count').reset_index()
# Out:
#         Data Type  Count
# 0           int64      1
# 1         float64     53
# 2  datetime64[ns]      1
# 3          object      5

# %%
data_type.loc[data_type['Data Type'] == 'object']
# Out:
#                         Count Data Type
# 24             hashottuborspa    object
# 34  propertycountylandusecode    object
# 36         propertyzoningdesc    object
# 51              fireplaceflag    object
# 57         taxdelinquencyflag    object

# %%
# store labels of all numerical varibales:
cate_X = data_type.loc[data_type['Data Type'] == 'object']
categorical_features = cate_X['Count'].values
categorical_features
# Out:
# array(['hashottuborspa', 'propertycountylandusecode',
#        'propertyzoningdesc', 'fireplaceflag', 'taxdelinquencyflag'],
#       dtype=object)

# %% [markdown]
# ### -> We found couple non-numerical data entries. We will deal with those features automatically later by using CatBoost.

# %% [markdown]
# ## 1.3 Plots of y:

# %%
# Distribution of y (outlier if any):

import warnings
warnings.filterwarnings('ignore')
merged_train_data['logerror'].loc[merged_train_data['logerror']>np.percentile(merged_train_data.logerror.values, 98)] = np.percentile(merged_train_data.logerror.values, 98)
merged_train_data['logerror'].loc[merged_train_data['logerror']<np.percentile(merged_train_data.logerror.values, 2)] = np.percentile(merged_train_data.logerror.values, 2)

plot.figure(figsize=(13,9))
sns.distplot(merged_train_data.logerror.values,kde=False,color='yellow', bins=30)
plot.xlabel('logerror values', fontsize=14)
plot.show()

# %% [markdown]
# ### -> We can see from graph above, it is a very good normal distribution. Since logerror = log(Zestimate) - log(actual price), negative logerror value means Zestimate underestimated, positive value means Zestimate overestimated. We can see from this normal distribution, it estimates pretty accurate most of the time.
# ### -> In my fitted model, we need to find out when Zesimate does well and when it doesn't.

# %% [markdown]
# # 2. Feature Engineering

# %% [markdown]
# ## 2.1 Deal with missing data:
# ### * Of course, if we have more time, we can do more on this.

# %%
missing_data = merged_train_data.isnull().sum(axis=0).reset_index()
missing_data.columns = ['names', 'counts']
missing_data = missing_data.sort_values(by='counts')

fig, axes = plot.subplots(figsize=(11,17))
axes.barh(np.arange(missing_data.shape[0]), missing_data.counts.values, alpha=0.9,color='purple')
axes.set_title("Total number of missing values for every column")
axes.set_yticks(np.arange(missing_data.shape[0]))
axes.set_yticklabels(missing_data.names.values, rotation='horizontal')
plot.show()

# %% [markdown]
# ### -> We can see a lot of NaN values from this spreadsheet. Work on this:

# %%
# drop columns with more than 800000 Nan:

missing_data = missing_data.sort_values(by='counts')
missing_data
# Out:
#                            names  counts
# 0                       parcelid       0
# 27                     longitude       0
# 35         propertylandusetypeid       0
# 37        rawcensustractandblock       0
# 39                regionidcounty       0
# 42                       roomcnt       0
# 26                      latitude       0
# 19                          fips       0
# 6                    bathroomcnt       0
# 54                assessmentyear       0
# 2                transactiondate       0
# 1                       logerror       0
# 7                     bedroomcnt       0
# 34     propertycountylandusecode       1
# 55         landtaxvaluedollarcnt       1
# 53             taxvaluedollarcnt       1
# 56                     taxamount       6
# 41                   regionidzip      35
# 52    structuretaxvaluedollarcnt     380
# 59           censustractandblock     605
# 13  calculatedfinishedsquarefeet     661
# 49                     yearbuilt     756
# 21                   fullbathcnt    1182
# 10             calculatedbathnbr    1182
# 38                  regionidcity    1803
# 14          finishedsquarefeet12    4679
# 28             lotsizesquarefeet   10150
# 46                       unitcnt   31922
# 36            propertyzoningdesc   31962
# 9          buildingqualitytypeid   32911
# 25         heatingorsystemtypeid   34195
# 40          regionidneighborhood   54263
# 23               garagetotalsqft   60338
# 22                  garagecarcnt   60338
# 3          airconditioningtypeid   61494
# 50               numberofstories   69705
# 29                       poolcnt   72374
# 33                   pooltypeid7   73578
# 44           threequarterbathnbr   78266
# 20                  fireplacecnt   80668
# 12      finishedfloor1squarefeet   83419
# 17          finishedsquarefeet50   83419
# 16          finishedsquarefeet15   86711
# 47            yardbuildingsqft17   87629
# 24                hashottuborspa   87910
# 57            taxdelinquencyflag   88492
# 58            taxdelinquencyyear   88492
# 32                   pooltypeid2   89071
# 31                  pooltypeid10   89114
# 30                   poolsizesum   89306
# 11                    decktypeid   89617
# 18           finishedsquarefeet6   89854
# 45        typeconstructiontypeid   89976
# 4       architecturalstyletypeid   90014
# 51                 fireplaceflag   90053
# 48            yardbuildingsqft26   90180
# 43                   storytypeid   90232
# 5                   basementsqft   90232
# 15          finishedsquarefeet13   90242
# 8            buildingclasstypeid   90259

# %%
merged_train_data = merged_train_data.drop(['buildingclasstypeid', 'finishedsquarefeet13','basementsqft',
                        'storytypeid','yardbuildingsqft26','fireplaceflag','architecturalstyletypeid',
                       'typeconstructiontypeid','finishedsquarefeet6','decktypeid','poolsizesum',
                       'pooltypeid10','pooltypeid2','taxdelinquencyyear','taxdelinquencyflag',
                       'fireplacecnt','finishedfloor1squarefeet','finishedfloor1squarefeet','finishedsquarefeet50',
                       'finishedsquarefeet15','yardbuildingsqft17','hashottuborspa'], axis=1)

# %%
# fill with mean value: 
merged_data_means = merged_train_data.mean(axis=0)
merged_train_data = merged_train_data.fillna(merged_data_means)
merged_train_data = merged_train_data.fillna('Empty')
merged_train_data.head()
# Out:
#    parcelid  logerror transactiondate  airconditioningtypeid  bathroomcnt  bedroomcnt  \
# 0  11016594     0.028      2016-01-01                  1.000          2.0         3.0
# 1  14366692    -0.168      2016-01-01                  1.816          3.5         4.0
# 2  12098116    -0.004      2016-01-01                  1.000          3.0         2.0
# 3  12643413     0.022      2016-01-02                  1.000          2.0         2.0
# 4  14432541    -0.005      2016-01-02                  1.816          2.5         4.0
#
#    buildingqualitytypeid  calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                  4.000                2.0                        1684.0                1684.0
# 1                  5.565                3.5                        2263.0                2263.0
# 2                  4.000                3.0                        2217.0                2217.0
# 3                  4.000                2.0                         839.0                 839.0
# 4                  5.565                2.5                        2283.0                2283.0
#
#    ...  threequarterbathnbr  unitcnt  yearbuilt  numberofstories  structuretaxvaluedollarcnt  \
# 0  ...                1.009     1.00     1959.0            1.441                    122754.0
# 1  ...                1.000     1.11     2014.0            1.441                    346458.0
# 2  ...                1.009     1.00     1940.0            1.441                     61994.0
# 3  ...                1.009     1.00     1987.0            1.441                    171518.0
# 4  ...                1.000     1.11     1981.0            2.000                    169574.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  censustractandblock
# 0           360170.0          2015.0               237416.0    6735.88            6.037e+13
# 1           585529.0          2015.0               239071.0   10153.02            6.049e+13
# 2           119906.0          2015.0                57912.0   11484.48            6.037e+13
# 3           244880.0          2015.0                73362.0    3048.74            6.037e+13
# 4           434551.0          2015.0               264977.0    5488.96            6.059e+13
#
# [5 rows x 39 columns]

# %% [markdown]
# ## 2.2 Multicolinarity (multivariate dependence - VIF):

# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# 使用difference方法，它返回的是索引的差集
df_num_X = merged_train_data[merged_train_data.columns.difference(['hashottuborspa', 
                                                              'propertycountylandusecode', 
                                                              'propertyzoningdesc', 
                                                              'fireplaceflag', 
                                                              'taxdelinquencyflag',
                                                              'transactiondate',
                                                              'logerror'])] 
                                                            # remove all non-numerical features and y, in PCA


X_variables = df_num_X
vif_data = pd.DataFrame()
vif_data["feature"] = X_variables.columns
vif_data["VIF"] = [variance_inflation_factor(X_variables.values, i) for i in range(len(X_variables.columns))]

# %%
# calculated the VIF for my X variables:
vif_data
# Out:
#                          feature        VIF
# 0          airconditioningtypeid      1.255
# 1                 assessmentyear      0.000
# 2                    bathroomcnt     25.263
# 3                     bedroomcnt      2.577
# 4          buildingqualitytypeid      1.292
# 5              calculatedbathnbr     83.200
# 6   calculatedfinishedsquarefeet     18.743
# 7            censustractandblock     94.638
# 8           finishedsquarefeet12     16.047
# 9                           fips  13002.011
# 10                   fullbathcnt     52.783
# 11                  garagecarcnt      1.887
# 12               garagetotalsqft      2.374
# 13         heatingorsystemtypeid      1.291
# 14         landtaxvaluedollarcnt   1566.499
# 15                      latitude      2.616
# 16                     longitude      4.110
# 17             lotsizesquarefeet      1.065
# 18               numberofstories      1.178
# 19                      parcelid      2.017
# 20                       poolcnt      0.000
# 21                   pooltypeid7      0.000
# 22         propertylandusetypeid      1.534
# 23        rawcensustractandblock  13020.344
# 24                  regionidcity      1.031
# 25                regionidcounty      8.325
# 26          regionidneighborhood      1.165
# 27                   regionidzip      1.011
# 28                       roomcnt      3.643
# 29    structuretaxvaluedollarcnt    430.008
# 30                     taxamount     10.658
# 31             taxvaluedollarcnt   2995.308
# 32           threequarterbathnbr      1.074
# 33                       unitcnt      1.243
# 34                     yearbuilt      2.185

# %% [markdown]
# ### -> variables with very higher are highly corelated with other varibles -> multi-collinearity -> remove from the model (* Generally, the threshold is 5.).

# %% [markdown]
# ## 2.3 Then delete those highly-correlated variables (it's part of Feature Selection):

# %%
# 使用difference方法，它返回的是索引的差集
merged_train_data_nomul = merged_train_data[merged_train_data.columns.difference(['bathroomcnt', 
                                                              'calculatedbathnbr', 
                                                              'calculatedfinishedsquarefeet', 
                                                              'censustractandblock', 
                                                              'finishedfloor1squarefeet',
                                                              'finishedsquarefeet12',
                                                              'finishedsquarefeet15',
                                                              'finishedsquarefeet50',
                                                              'fips',
                                                              'fullbathcnt',
                                                              'landtaxvaluedollarcnt',
                                                              'rawcensustractandblock',
                                                              'regionidcounty',
                                                              'structuretaxvaluedollarcnt',
                                                              'taxamount',
                                                              'taxvaluedollarcnt'])] 
                                                            # remove all non-numerical features and y, in PCA

# %%
merged_train_data_nomul.shape
# Out:
# (90275, 26)

# %% [markdown]
# ### * Of couere, more work on feature selection (e.g., stepwise regression) can be done hear, if more data is given.

# %% [markdown]
# # 3. Model Build

# %% [markdown]
# ### * CatBoost can automatically deal with sophiscated categorical variables, using mean-encoding.

# %%
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (7.6.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipywidgets) (6.6.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipywidgets) (1.0.2)
# Requirement already satisfied: ipython>=4.0.0 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipywidgets) (7.30.1)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipywidgets) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipywidgets) (3.5.2)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: appnope in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: jupyter-client<8.0 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.1.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: pexpect>4.3 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (60.5.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.24)
# Requirement already satisfied: jedi>=0.16 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pickleshare in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: backcall in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pygments in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (2.10.0)
# Requirement already satisfied: decorator in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (5.1.0)
# Requirement already satisfied: jupyter-core in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets) (4.9.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets) (4.2.1)
# Requirement already satisfied: notebook>=4.4.1 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (21.4.0)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: entrypoints in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (0.3)
# Requirement already satisfied: pyzmq>=13 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.5.4)
# Requirement already satisfied: jinja2 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.12.1)
# Requirement already satisfied: nbconvert in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.3.0)
# Requirement already satisfied: argon2-cffi in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.8.0)
# Requirement already satisfied: prometheus-client in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.12.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six>=1.5 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.1)
# Requirement already satisfied: bleach in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: defusedxml in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: testpath in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.9)
# Requirement already satisfied: cffi>=1.0.1 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.15.0)
# Requirement already satisfied: packaging in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3)
# Requirement already satisfied: webencodings in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pycparser in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/lyuxiaoxi/miniforge3/lib/python3.9/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.7)

# %% [markdown]
# ## 3.1 Find all catogorical variables:

# %%
data_type = merged_train_data_nomul.dtypes.reset_index()
data_type.columns = ["Count", "Data Type"]
data_type.groupby("Data Type").aggregate('count').reset_index()

# store labels of all numerical varibales:
cate_X = data_type.loc[data_type['Data Type'] == 'object']
categorical_features = cate_X['Count'].values
categorical_features
# Out:
# array(['propertycountylandusecode', 'propertyzoningdesc'], dtype=object)

# %% [markdown]
# ## 3.2 Create a Validation Dataset:

# %%
y = merged_train_data_nomul['logerror']
X = merged_train_data_nomul[merged_train_data_nomul.columns.difference(['logerror','transactiondate'])] 
                                                                    # 'transactiondate' is not a variable

# %%
from sklearn.model_selection import train_test_split
# https://www.analyseup.com/python-machine-learning/catboost-python-tutorial.html
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101, stratify=y)

# %%
X_train.shape, y_train.shape, y_train.shape, y_test.shape, X_test.shape
# Out:
# ((72220, 24), (72220,), (72220,), (18055,), (18055, 24))

# %% [markdown]
# ## 3.3 Train Model:

# %%
import numpy as np
from catboost import Pool, CatBoostRegressor

# specify the training parameters 
    ## https://catboost.ai/en/docs/references/training-parameters/common#learning_rate
model = CatBoostRegressor(iterations=50, # if too large -> maybe overfitting + long run time
                          learning_rate=0.05, # the default value is 0.03
                          cat_features=categorical_features,  # categorical_features_indices
                          loss_function='MAPE')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/08/s7htmd_10rv94m8swrks89f40000gn/T/ipykernel_20517/2505166359.py in <module>
#       1 import numpy as np
# ----> 2 from catboost import Pool, CatBoostRegressor
#       3
#       4 # specify the training parameters
#       5     ## https://catboost.ai/en/docs/references/training-parameters/common#learning_rate
#
# ModuleNotFoundError: No module named 'catboost'

# %%
model.fit(
        X_train, y_train,
        verbose_eval=100, 
        early_stopping_rounds=50,
        eval_set=(X_test, y_test),
        use_best_model=False,
        plot=True
);

# %%
# Get predictions
preds = model.predict(X_test)
preds

# %%
type(preds)

# %%
preds=pd.DataFrame(preds)
preds

# %% [markdown]
# # 4. Evalution:

# %% [markdown]
# ## 4.1 Performance Evaluation (MAE):

# %%
y_test

# %%
type(y_test)

# %% [markdown]
# ### -> MAE:

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, preds)

# %% [markdown]
# # 5. Model Explanation with SHAP

# %%
# https://www.kaggle.com/mcsweena/feature-importance-with-catboost-and-shap
import shap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/08/s7htmd_10rv94m8swrks89f40000gn/T/ipykernel_20517/127514784.py in <module>
#       1 # https://www.kaggle.com/mcsweena/feature-importance-with-catboost-and-shap
# ----> 2 import shap
#
# ModuleNotFoundError: No module named 'shap'

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
explainer = shap.TreeExplainer(model)

# %%
shap_values = explainer.shap_values(Pool(X_train, y_train, cat_features=categorical_features))

# %% [markdown]
# ### First, let's take some rows at random and look at the shapley contribution each feature made to each prediction:

# %%
shap.force_plot(explainer.expected_value, shap_values[0,:], X_train.iloc[0,:])
# Out:
# <div id='iZM2NGIB0H4045W4GXYQ4'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.005637599198082837, "outValue": 0.0028900900674191108, "link": "identity", "featureNames": ["airconditioningtypeid", "assessmentyear", "bedroomcnt", "buildingqualitytypeid", "garagecarcnt", "garagetotalsqft", "heatingorsystemtypeid", "latitude", "longitude", "lotsizesquarefeet", "numberofstories", "parcelid", "poolcnt", "pooltypeid7", "propertycountylandusecode", "propertylandusetypeid", "propertyzoningdesc", "regionidcity", "regionidneighborhood", "regionidzip", "roomcnt", "threequarterbathnbr", "unitcnt", "yearbuilt"], "features": {"0": {"effect": 0.0003432939464923172, "value": 1.0}, "2": {"effect": 0.0006917236716772149, "value": 4.0}, "3": {"effect": 0.00010384340712315119, "value": 4.0}, "4": {"effect": -1.2290119539560702e-05, "value": 1.8120052109429803}, "5": {"effect": -1.3345571299104217e-05, "value": 345.5212279119484}, "6": {"effect": 0.0001294970623214105, "value": 2.0}, "7": {"effect": -0.0008033244480025405, "value": 34205455.0}, "8": {"effect": 6.669357030861188e-05, "value": -118445500.0}, "9": {"effect": -0.00033170434724457434, "value": 8368.0}, "10": {"effect": -0.00033680970781849146, "value": 1.4407389402041808}, "11": {"effect": -0.0002947146850967624, "value": 10826256.0}, "14": {"effect": -0.001533762942969347, "value": "0101"}, "15": {"effect": -0.0001154114204051828, "value": 261.0}, "16": {"effect": -6.717730715982431e-06, "value": "LAR1"}, "17": {"effect": -8.708204013004938e-05, "value": 12447.0}, "18": {"effect": 2.427437777446522e-05, "value": 41466.0}, "19": {"effect": 0.00022275039730136004, "value": 96414.0}, "20": {"effect": -1.5006021016559107e-05, "value": 0.0}, "21": {"effect": -2.1876838600169434e-05, "value": 1.0087434424181863}, "22": {"effect": 1.5211007147949183e-05, "value": 1.0}, "23": {"effect": -0.0007727506979718823, "value": 1957.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iZM2NGIB0H4045W4GXYQ4')
#   );
# </script>

# %% [markdown]
# ### -> Row 0 output is lower than the model baseline - this means the row would be predicted as being 0. What's contributing to this? Well propertycountylanduseconds and xxx appear to have the largest negative impact on the output, while bedroomcnt has the largest positive impact. Outside of bedroomcnt, no other features are having any meaningful positive impact on the predcition.

# %% [markdown]
# ### To get a deeper insight into what's actually going on here, decoding the features back into their original states might shed some more light:

# %%
shap.force_plot(explainer.expected_value, shap_values[4,:], X_train.iloc[4,:])
# Out:
# <div id='iETRNADYINQ80K8IU4RFQ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.005637599198082837, "outValue": 0.01100831925073753, "link": "identity", "featureNames": ["airconditioningtypeid", "assessmentyear", "bedroomcnt", "buildingqualitytypeid", "garagecarcnt", "garagetotalsqft", "heatingorsystemtypeid", "latitude", "longitude", "lotsizesquarefeet", "numberofstories", "parcelid", "poolcnt", "pooltypeid7", "propertycountylandusecode", "propertylandusetypeid", "propertyzoningdesc", "regionidcity", "regionidneighborhood", "regionidzip", "roomcnt", "threequarterbathnbr", "unitcnt", "yearbuilt"], "features": {"0": {"effect": 0.00029603493562168693, "value": 1.0}, "2": {"effect": -0.0005927915015831095, "value": 3.0}, "3": {"effect": 0.0002445966015113999, "value": 4.0}, "4": {"effect": -7.787219792201587e-06, "value": 1.8120052109429803}, "5": {"effect": -3.082927534701571e-05, "value": 345.5212279119484}, "6": {"effect": 0.0001723019052982021, "value": 2.0}, "7": {"effect": -8.254016181573908e-05, "value": 33984064.0}, "8": {"effect": -0.00014189787884401786, "value": -117954897.0}, "9": {"effect": 0.0004324735256087236, "value": 1525.0}, "10": {"effect": 0.0001467079104122408, "value": 1.4407389402041808}, "11": {"effect": 0.0005055595596908805, "value": 12832862.0}, "14": {"effect": -0.00044036320820231534, "value": "010D"}, "15": {"effect": 0.0004474057573891789, "value": 269.0}, "16": {"effect": 0.0034853153934711156, "value": "LCRPD90005"}, "17": {"effect": 0.00019380484693189105, "value": 45602.0}, "18": {"effect": -3.6667688767045216e-05, "value": 190646.5402365878}, "19": {"effect": 0.0002023475602593192, "value": 96489.0}, "20": {"effect": -1.7290955070665822e-05, "value": 0.0}, "21": {"effect": -3.427467170880371e-05, "value": 1.0087434424181863}, "22": {"effect": 0.00015147915628649242, "value": 1.0}, "23": {"effect": 0.00047713546130447797, "value": 1975.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iETRNADYINQ80K8IU4RFQ')
#   );
# </script>

# %% [markdown]
# - Row 4 output is higher than the baseline. So, what's contributing to this? ...

# %% [markdown]
# ### This would be a long, long process to run through this exercise with many rows. So to speed up the insights, lets stack a number of them horizontally and see what we get:

# %%
# visualize the training set predictions
shap.force_plot(explainer.expected_value, shap_values[0:50,:], X_train.iloc[0:50,:])
# Out:
# <div id='iL9VIL726Y3ZPOSPEDLZ8'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.005637599198082837, "link": "identity", "featureNames": ["airconditioningtypeid", "assessmentyear", "bedroomcnt", "buildingqualitytypeid", "garagecarcnt", "garagetotalsqft", "heatingorsystemtypeid", "latitude", "longitude", "lotsizesquarefeet", "numberofstories", "parcelid", "poolcnt", "pooltypeid7", "propertycountylandusecode", "propertylandusetypeid", "propertyzoningdesc", "regionidcity", "regionidneighborhood", "regionidzip", "roomcnt", "threequarterbathnbr", "unitcnt", "yearbuilt"], "explanations": [{"outValue": 0.0028900900674191108, "simIndex": 44.0, "features": {"0": {"effect": 0.0003432939464923172, "value": 1.0}, "1": {"effect": 0.0, "value": 2015.0}, "2": {"effect": 0.0006917236716772149, "value": 4.0}, "3": {"effect": 0.00010384340712315119, "value": 4.0}, "4": {"effect": -1.2290119539560702e-05, "value": 1.8120052109429803}, "5": {"effect": -1.3345571299104217e-05, "value": 345.5212279119484}, "6": {"effect": 0.0001294970623214105, "value": 2.0}, "7": {"effect": -0.0008033244480025405, "value": 34205455.0}, "8": {"effect": 6.669357030861188e-05, "value": -118445500.0}, "9": {"effect": -0.00033170434724457434, "value": 8368.0}, "10": {"effect": -0.00033680970781849146, "value": 1.4407389402041808}, "11": {"effect": -0.0002947146850967624, "value": 10826256}, "12": {"effect": 0.0, "value": 1.0}, "13": {"effect": 0.0, "value": 1.0}, "14": {"effect": -0.001533762942969347, "value": "0101"}, "15": {"effect": -0.0001154114204051828, "value": 261.0}, "16": {"effect": -6.717730715982431e-06, "value": "LAR1"}, "17": {"effect": -8.708204013004938e-05, "value": 12447.0}, "18": {"effect": 2.427437777446522e-05, "value": 41466.0}, "19": {"effect": 0.00022275039730136004, "value": 96414.0}, "20": {"effect": -1.5006021016559107e-05, "value": 0.0}, "21": {"effect": -2.1876838600169434e-05, "value": 1.0087434424181863}, "22": {"effect": 1.5211007147949183e-05, "value": 1.0}, "23": {"effect": -0.0007727506979718823, "value": 1957.0}}}, {"outValue": 0.011324061499935326, "simIndex": 17.0, "features": {"0": {"effect": 0.00031835374086804655, "value": 1.0}, "1": {"effect": 0.0, "value": 2015.0}, "2": {"effect": -0.0009540610100672055, "value": 2.0}, "3": {"effect": 0.0012104892293749636, "value": 10.0}, "4": {"effect": -5.45557433413467e-06, "value": 1.8120052109429803}, "5": {"effect": -2.1043877560631105e-05, "value": 345.5212279119484}, "6": {"effect": 0.0001281388394591662, "value": 2.0}, "7": {"effect": 0.0004544993358644916, "value": 34048500.0}, "8": {"effect": -1.5784464701407823e-05, "value": -118535000.0}, "9": {"effect": 0.000802998154338093, "value": 17476.0}, "10": {"effect": 7.205814454915813e-05, "value": 1.4407389402041808}, "11": {"effect": 0.000267494076882558, "value": 11664173}, "12": {"effect": 0.0, "value": 1.0}, "13": {"effect": 0.0, "value": 1.0}, "14": {"effect": -0.0007157534895217839, "value": "010C"}, "15": {"effect": 1.0663894328246566e-05, "value": 266.0}, "16": {"effect": 0.001957291444805645, "value": "LAR3"}, "17": {"effect": 0.00012954094483065318, "value": 12447.0}, "18": {"effect": 0.00012275350322352158, "value": 19810.0}, "19": {"effect": 0.0003793275398619293, "value": 96120.0}, "20": {"effect": 6.69628495073005e-08, "value": 0.0}, "21": {"effect": -2.2860730469380223e-05, "value": 1.0087434424181863}, "22": {"effect": 0.00017084674970057722, "value": 1.0}, "23": {"effect": 0.0013968988875704743, "value": 2000.0}}}, {"outValue": 0.004528886317800492, "simIndex": 24.0, "features": {"0": {"effect": 2.4959979366522833e-05, "value": 1.8163719120252944}, "1": {"effect": 0.0, "value": 2015.0}, "2": {"effect": -0.0006106610250623591, "value": 2.0}, "3": {"effect": -4.073653820261384e-05, "value": 5.565406875392232}, "4": {"effect": -1.1036846980454136e-05, "value": 1.0}, "5": {"effect": 1.793567390809572e-05, "value": 0.0}, "6": {"effect": 5.2005547579380006e-05, "value": 3.9269793152639085}, "7": {"effe ...

# %% [markdown]
# - It gives a great visual representation of how different values affect predictions. It also highlights certain rows to look into deeper using the single row view above.

# %% [markdown]
# ## Feature Importance:

# %%
# feature importance plot
shap.summary_plot(shap_values, X_train, plot_type="bar")

# %% [markdown]
# - Ok, so the most importance features in this model are bedroomcnt, ...

# %%
# summarize the effects of all the features
shap.summary_plot(shap_values, X_train)

# %% [markdown]
# ### First, a quick recap as to what's going on in this plot. The plot shows a cumulation of many dots. The dots have 3 characteristics:
# - 1. The vertical location of the dots show what feature they are depicting
# - 2. Color shows whether that feature value was high or low for that row of the dataset
# - 3. Horizontal location shows whether the effect of that value caused a higher or lower prediction.

# %% [markdown]
# ### Let's look at some features in particular:
# - The feature "bedroomcnt" has the largest impact on the model and interestingly the higher the value, the more positive the contribution the feature gave to the model prediction.
# - The feature "roomcnt" has very little impact on the models predictions. When this feature is with very low values (0 or 1), it has almost NO impact on the model prediction; but if the value is higher, it may have either negative or positive impact on the model prediction.
